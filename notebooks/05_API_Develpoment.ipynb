# %% [markdown]
# # MLOps Workshop: API-Entwicklung mit FastAPI
#
# ## Einführung
# In diesem Notebook entwickeln wir eine REST-API mit FastAPI für unser Customer Churn Prediction Modell. Wir werden Best Practices für ML-Model-Serving implementieren, einschließlich Input-Validierung, Fehlerbehandlung und Performance-Optimierung.
#
# ## Lernziele
# Nach Abschluss dieses Notebooks können Sie:
# - Eine REST-API mit FastAPI entwickeln
# - ML-Modelle über HTTP-Endpoints bereitstellen
# - Input-Validierung und Fehlerbehandlung implementieren
# - API-Tests schreiben und durchführen
# - API-Performance überwachen
#
# ## Voraussetzungen
# - Abgeschlossenes Modelltraining und -evaluierung (Notebooks 03 und 04)
# - Grundlegendes Verständnis von HTTP und REST-APIs
#
# ## 1. Setup und Installation
#
# Zuerst installieren wir die benötigten Bibliotheken:

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import numpy as np
from fastapi import FastAPI, HTTPException, Request
from fastapi.middleware.cors import CORSMiddleware
from fastapi.responses import JSONResponse
from pydantic import BaseModel, Field
from typing import List, Literal
from datetime import datetime
import time
import logging
from mlflow.tracking import MlflowClient
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)
# MLflow Setup
mlflow.set_tracking_uri("file:../mlruns")
client = mlflow.client.MlflowClient()

# Modell laden
model_name = "loan_default_predictor"
model_version = client.get_latest_versions(model_name, stages=["Staging"])[0]
print(model_version.run_id)
model = mlflow.sklearn.load_model(f"runs:/{model_version.run_id}/model")
# Out:
# C:\Users\bjoer\AppData\Local\Temp\ipykernel_31684\3562407901.py:24: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   model_version = client.get_latest_versions(model_name, stages=["Staging"])[0]
# 35b5f3a62d264c1fa8fd7d506058c7af
# ...

# %%
# Pydantic models

class LoanFeatures(BaseModel):
    credit_policy: int = Field(..., ge=0, le=1, description="1 = erfüllt Kreditrichtlinie, 0 = nicht erfüllt")
    purpose: Literal[
        "all_other",
        "credit_card",
        "debt_consolidation",
        "educational",
        "home_improvement",
        "major_purchase",
        "small_business"
    ]
    int_rate: float = Field(..., ge=0, le=1, description="Zinssatz als Anteil, z.B. 0.11 für 11%")
    installment: float = Field(..., gt=0)
    log_annual_inc: float = Field(..., gt=0)
    dti: float = Field(..., ge=0)
    fico: int = Field(..., ge=300, le=850)
    days_with_cr_line: float = Field(..., ge=0)
    revol_bal: float = Field(..., ge=0)
    revol_util: float = Field(..., ge=0, le=150)
    inq_last_6mths: int = Field(..., ge=0)
    delinq_2yrs: int = Field(..., ge=0)
    pub_rec: int = Field(..., ge=0)

class BatchLoanRequest(BaseModel):
    loans: List[LoanFeatures]

# %%
# FastAPI-Anwendung

import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("loan_api")

app = FastAPI(
    title="Loan Default Prediction API",
    description="API zur Vorhersage von Kreditausfallrisiken",
    version="1.0.0"
)

# CORS
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)

# Erwartete Modellspalten aus dem Preprocessing/Training
MODEL_COLUMNS = [
    "credit.policy",
    "int.rate",
    "installment",
    "log.annual.inc",
    "dti",
    "fico",
    "days.with.cr.line",
    "revol.bal",
    "revol.util",
    "inq.last.6mths",
    "delinq.2yrs",
    "pub.rec",
    "debt_burden_ratio",
    "dti_to_fico",
    "int_rate_to_fico",
    "revol_bal_to_inc",
    "purpose_credit_card",
    "purpose_debt_consolidation",
    "purpose_educational",
    "purpose_home_improvement",
    "purpose_major_purchase",
    "purpose_small_business"
]

def preprocess_input(loan: LoanFeatures) -> pd.DataFrame:
    """
    Wandelt API-Input in das Format um, das das Modell erwartet.
    """
    annual_income = np.exp(loan.log_annual_inc)

    row = {
        "credit.policy": loan.credit_policy,
        "int.rate": loan.int_rate,
        "installment": loan.installment,
        "log.annual.inc": loan.log_annual_inc,
        "dti": loan.dti,
        "fico": loan.fico,
        "days.with.cr.line": loan.days_with_cr_line,
        "revol.bal": loan.revol_bal,
        "revol.util": loan.revol_util,
        "inq.last.6mths": loan.inq_last_6mths,
        "delinq.2yrs": loan.delinq_2yrs,
        "pub.rec": loan.pub_rec,

        # Feature Engineering
        "debt_burden_ratio": loan.installment * loan.dti / annual_income,
        "dti_to_fico": loan.dti / loan.fico,
        "int_rate_to_fico": loan.int_rate / loan.fico,
        "revol_bal_to_inc": loan.revol_bal / annual_income,

        # Dummy-Spalten
        "purpose_credit_card": 0,
        "purpose_debt_consolidation": 0,
        "purpose_educational": 0,
        "purpose_home_improvement": 0,
        "purpose_major_purchase": 0,
        "purpose_small_business": 0
    }

    # all_other = Basiskategorie
    if loan.purpose != "all_other":
        dummy_col = f"purpose_{loan.purpose}"
        if dummy_col in row:
            row[dummy_col] = 1

    return pd.DataFrame([row], columns=MODEL_COLUMNS)

@app.get("/")
def root():
    return {
        "message": "Loan Default Prediction API läuft",
        "model_name": str(model_name) if "model_name" in globals() else "unbekannt",
        "model_version": str(model_version.version) if "model_version" in globals() else "unbekannt",
        "timestamp": datetime.now().isoformat()
    }

@app.get("/health")
def health():
    return {
        "status": "ok",
        "model_loaded": "model" in globals() and model is not None,
        "model_name": str(model_name) if "model_name" in globals() else "unbekannt",
        "model_version": str(model_version.version) if "model_version" in globals() else "unbekannt"
    }

@app.post("/predict")
def predict(loan: LoanFeatures):
    if "model" not in globals() or model is None:
        raise HTTPException(status_code=500, detail="Modell ist nicht geladen.")

    try:
        input_df = preprocess_input(loan)
        prediction = model.predict(input_df)[0]

        probability = None
        if hasattr(model, "predict_proba"):
            probability = float(model.predict_proba(input_df)[0][1])

        return {
            "prediction": int(prediction),
            "default_risk_probability": probability,
            "interpretation": (
                "Zahlungsausfall wahrscheinlich"
                if int(prediction) == 1
                else "Kein Zahlungsausfall wahrscheinlich"
            )
        }

    except Exception as e:
        logger.exception("Fehler bei /predict")
        raise HTTPException(status_code=500, detail=f"Vorhersage fehlgeschlagen: {str(e)}")

@app.post("/predict_batch")
def predict_batch(request: BatchLoanRequest):
    if "model" not in globals() or model is None:
        raise HTTPException(status_code=500, detail="Modell ist nicht geladen.")

    try:
        frames = [preprocess_input(loan) for loan in request.loans]
        batch_df = pd.concat(frames, ignore_index=True)

        predictions = model.predict(batch_df)

        probabilities = [None] * len(predictions)
        if hasattr(model, "predict_proba"):
            probabilities = [float(p) for p in model.predict_proba(batch_df)[:, 1]]

        results = []
        for pred, prob in zip(predictions, probabilities):
            results.append({
                "prediction": int(pred),
                "default_risk_probability": prob,
                "interpretation": (
                    "Zahlungsausfall wahrscheinlich"
                    if int(pred) == 1
                    else "Kein Zahlungsausfall wahrscheinlich"
                )
            })

        return {
            "count": len(results),
            "results": results
        }

    except Exception as e:
        logger.exception("Fehler bei /predict_batch")
        raise HTTPException(status_code=500, detail=f"Batch-Vorhersage fehlgeschlagen: {str(e)}")

# %%
# Middleware und Error Handling

@app.middleware("http")
async def log_requests(request: Request, call_next):
    start_time = time.time()

    logger.info(f"Request gestartet: {request.method} {request.url.path}")

    try:
        response = await call_next(request)
        process_time = round(time.time() - start_time, 4)

        logger.info(
            f"Request beendet: {request.method} {request.url.path} | "
            f"Status: {response.status_code} | Dauer: {process_time}s"
        )

        response.headers["X-Process-Time"] = str(process_time)
        return response

    except Exception as e:
        process_time = round(time.time() - start_time, 4)
        logger.exception(
            f"Unhandled error bei {request.method} {request.url.path} "
            f"nach {process_time}s: {str(e)}"
        )
        return JSONResponse(
            status_code=500,
            content={"detail": "Interner Serverfehler"}
        )

@app.exception_handler(Exception)
async def global_exception_handler(request: Request, exc: Exception):
    logger.exception(f"Global exception handler: {exc}")
    return JSONResponse(
        status_code=500,
        content={"detail": "Unerwarteter Fehler in der API"}
    )

# %%
import logging

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("loan_api")

# %%
from fastapi.testclient import TestClient

test_client = TestClient(app)

def test_root():
    response = test_client.get("/")
    assert response.status_code == 200
    data = response.json()
    assert "message" in data
    assert data["model_name"] == "loan_default_predictor"

def test_health():
    response = test_client.get("/health")
    assert response.status_code == 200
    data = response.json()
    assert data["status"] == "ok"
    assert data["model_loaded"] is True

def test_predict():
    sample_payload = {
        "credit_policy": 1,
        "purpose": "debt_consolidation",
        "int_rate": 0.12,
        "installment": 250.0,
        "log_annual_inc": 10.5,
        "dti": 14.0,
        "fico": 720,
        "days_with_cr_line": 4500.0,
        "revol_bal": 5000.0,
        "revol_util": 35.0,
        "inq_last_6mths": 1,
        "delinq_2yrs": 0,
        "pub_rec": 0
    }

    response = test_client.post("/predict", json=sample_payload)
    assert response.status_code == 200

    data = response.json()
    assert "prediction" in data
    assert data["prediction"] in [0, 1]
    assert "default_risk_probability" in data

def test_predict_batch():
    sample_payload = {
        "loans": [
            {
                "credit_policy": 1,
                "purpose": "debt_consolidation",
                "int_rate": 0.12,
                "installment": 250.0,
                "log_annual_inc": 10.5,
                "dti": 14.0,
                "fico": 720,
                "days_with_cr_line": 4500.0,
                "revol_bal": 5000.0,
                "revol_util": 35.0,
                "inq_last_6mths": 1,
                "delinq_2yrs": 0,
                "pub_rec": 0
            },
            {
                "credit_policy": 0,
                "purpose": "small_business",
                "int_rate": 0.18,
                "installment": 420.0,
                "log_annual_inc": 10.0,
                "dti": 22.0,
                "fico": 650,
                "days_with_cr_line": 3000.0,
                "revol_bal": 12000.0,
                "revol_util": 68.0,
                "inq_last_6mths": 3,
                "delinq_2yrs": 1,
                "pub_rec": 0
            }
        ]
    }

    response = test_client.post("/predict_batch", json=sample_payload)
    assert response.status_code == 200

    data = response.json()
    assert "count" in data
    assert data["count"] == 2
    assert len(data["results"]) == 2

def test_predict_invalid_input():
    invalid_payload = {
        "credit_policy": 1,
        "purpose": "debt_consolidation",
        "int_rate": -0.5,   # ungültig
        "installment": 250.0,
        "log_annual_inc": 10.5,
        "dti": 14.0,
        "fico": 720,
        "days_with_cr_line": 4500.0,
        "revol_bal": 5000.0,
        "revol_util": 35.0,
        "inq_last_6mths": 1,
        "delinq_2yrs": 0,
        "pub_rec": 0
    }

    response = test_client.post("/predict", json=invalid_payload)
    assert response.status_code == 422

print("Tests werden ausgeführt...")
test_root()
test_health()
test_predict()
test_predict_batch()
test_predict_invalid_input()
print("Alle Tests erfolgreich bestanden.")
# Out:
# INFO:loan_api:Request gestartet: GET /
# INFO:loan_api:Request beendet: GET / | Status: 200 | Dauer: 0.0155s
# INFO:httpx:HTTP Request: GET http://testserver/ "HTTP/1.1 200 OK"
# INFO:loan_api:Request gestartet: GET /health
# INFO:loan_api:Request beendet: GET /health | Status: 200 | Dauer: 0.0051s
# INFO:httpx:HTTP Request: GET http://testserver/health "HTTP/1.1 200 OK"
# INFO:loan_api:Request gestartet: POST /predict
# INFO:loan_api:Request beendet: POST /predict | Status: 200 | Dauer: 0.0706s
# INFO:httpx:HTTP Request: POST http://testserver/predict "HTTP/1.1 200 OK"
# INFO:loan_api:Request gestartet: POST /predict_batch
# INFO:loan_api:Request beendet: POST /predict_batch | Status: 200 | Dauer: 0.0145s
# INFO:httpx:HTTP Request: POST http://testserver/predict_batch "HTTP/1.1 200 OK"
# INFO:loan_api:Request gestartet: POST /predict
# INFO:loan_api:Request beendet: POST /predict | Status: 422 | Dauer: 0.0056s
# ...

# %% [markdown]
# ## 2. API-Entwicklung
#
# ### Aufgabe 1: Input-Validierung mit Pydantic
# Erstellen Sie Pydantic-Modelle für die API-Requests.
#
# <details>
# <summary>👉 Lösung anzeigen</summary>
#
# ```python
# # Pydantic models
# class CustomerFeatures(BaseModel):
#     """Pydantic model for customer features"""
#     gender: int = Field(..., ge=0, le=1, description="Gender (0=male, 1=female)")
#     tenure: float = Field(..., ge=0, description="Customer tenure in months")
#     MonthlyCharges: float = Field(..., ge=0, description="Monthly charges in dollars")
#     TotalCharges: float = Field(..., ge=0, description="Total charges in dollars")
#     AvgCostPerService: float = Field(..., ge=0, description="Average cost per service")
#     CustomerAge: float = Field(..., ge=0, le=120, description="Customer age in years")
#
#     @validator('TotalCharges')
#     def validate_total_charges(cls, v, values):
#         """Validate that TotalCharges makes sense given MonthlyCharges and tenure"""
#         if 'MonthlyCharges' in values and 'tenure' in values:
#             if v > values['MonthlyCharges'] * values['tenure'] * 1.5:
#                 raise ValueError('TotalCharges seems unusually high given MonthlyCharges and tenure')
#         return v
#
#     class Config:
#         schema_extra = {
#             "example": {
#                 "gender": 1,
#                 "tenure": 12,
#                 "MonthlyCharges": 89.9,
#                 "TotalCharges": 1078.8,
#                 "AvgCostPerService": 29.97,
#                 "CustomerAge": 42
#             }
#         }
#
# class PredictionRequest(BaseModel):
#     """Pydantic model for batch prediction requests"""
#     data: List[CustomerFeatures]
#
# class PredictionResponse(BaseModel):
#     """Pydantic model for prediction responses"""
#     predictions: List[float]
#     prediction_time: datetime
#     model_version: str
#     request_id: str
# ```
# </details>

# %% [markdown]
# ### Aufgabe 2: FastAPI-Anwendung erstellen
# Implementieren Sie die FastAPI-Anwendung mit Endpoints.
#
# <details>
# <summary>👉 Lösung anzeigen</summary>
# Check main.py
# </details>

# %% [markdown]
# ### Aufgabe 3: Middleware und Error Handling
# Implementieren Sie Middleware für Logging und Error Handling.
#
# <details>
# <summary>👉 Lösung anzeigen</summary>
#
# ```python
# from fastapi import Request
# from fastapi.middleware.cors import CORSMiddleware
# import logging
# import time
#
# # Logging konfigurieren
# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)
#
# # Middleware für Request-Logging
# @app.middleware("http")
# async def log_requests(request: Request, call_next):
#     """
#     Middleware für Request-Logging und Performance-Monitoring
#     """
#     start_time = time.time()
#
#     # Request-Details loggen
#     logger.info(f"Request: {request.method} {request.url}")
#
#     # Request verarbeiten
#     response = await call_next(request)
#
#     # Performance-Metriken berechnen
#     process_time = time.time() - start_time
#     logger.info(f"Response time: {process_time:.3f} seconds")
#
#     # Response-Header hinzufügen
#     response.headers["X-Process-Time"] = str(process_time)
#
#     return response
#
# # CORS-Middleware hinzufügen
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],  # In Produktion einschränken!
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
#
# # Globaler Exception Handler
# @app.exception_handler(Exception)
# async def global_exception_handler(request: Request, exc: Exception):
#     """
#     Globaler Exception Handler für einheitliche Fehlerbehandlung
#     """
#     logger.error(f"Global exception: {exc}")
#     return JSONResponse(
#         status_code=500,
#         content={
#             "error": str(exc),
#             "timestamp": datetime.now().isoformat(),
#             "path": str(request.url)
#         }
#     )
# ```
# </details>

# %% [markdown]
# ## 3. API-Tests
#
# ### Aufgabe 4: Unit-Tests erstellen
# Implementieren Sie Unit-Tests für die API.
#
# <details>
# <summary>👉 Lösung anzeigen</summary>
# Check main_test.py
# </details>
