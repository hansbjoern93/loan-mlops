# %% [markdown]
# # Datenexploration und Validierung
#
# In diesem Notebook wird der Rohdatensatz zuerst gelesen, grob verstanden und anschließend validiert.
# Das Ziel ist, eine saubere Ausgangsbasis für die folgenden Schritte zu schaffen.
#
# **Ablauf in diesem Notebook**
#
# 1. Datensatz laden
# 2. Struktur und Wertebereiche prüfen
# 3. Kategorische und numerische Variablen anschauen
# 4. Daten mit Great Expectations validieren
# 5. Den validierten Datensatz speichern

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import great_expectations as ge

plt.style.use("seaborn-v0_8-darkgrid")
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# ## 1. Datensatz laden

# %%
df = pd.read_csv("../data/raw/loan_data.csv")
print(f"Datensatz erfolgreich geladen. Form: {df.shape}")
# Out:
# Datensatz erfolgreich geladen. Form: (9578, 14)

# %% [markdown]
# ## 2. Erste Dateninspektion

# %%
print("Shape:", df.shape)
print("\nDatentypen:")
print(df.dtypes)
print("\nFehlende Werte:")
print(df.isnull().sum())
# Out:
# Shape: (9578, 14)
#
# Datentypen:
# credit.policy          int64
# purpose               object
# int.rate             float64
# installment          float64
# log.annual.inc       float64
# dti                  float64
# fico                   int64
# days.with.cr.line    float64
# revol.bal              int64
# revol.util           float64
# inq.last.6mths         int64
# delinq.2yrs            int64
# pub.rec                int64
# not.fully.paid         int64
# dtype: object
#
# Fehlende Werte:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe(include="all")
# Out:
#         credit.policy             purpose     int.rate  installment  \
# count     9578.000000                9578  9578.000000  9578.000000
# unique            NaN                   7          NaN          NaN
# top               NaN  debt_consolidation          NaN          NaN
# freq              NaN                3957          NaN          NaN
# mean         0.804970                 NaN     0.122640   319.089413
# std          0.396245                 NaN     0.026847   207.071301
# min          0.000000                 NaN     0.060000    15.670000
# 25%          1.000000                 NaN     0.103900   163.770000
# 50%          1.000000                 NaN     0.122100   268.950000
# 75%          1.000000                 NaN     0.140700   432.762500
# max          1.000000                 NaN     0.216400   940.140000
#
#         log.annual.inc          dti         fico  days.with.cr.line  \
# count      9578.000000  9578.000000  9578.000000        9578.000000
# ...

# %%
print("Anzahl doppelter Zeilen:", df.duplicated().sum())
# Out:
# Anzahl doppelter Zeilen: 0

# %% [markdown]
# ## 3. Explorative Datenanalyse
#
# Zuerst werden die kategorischen Variablen betrachtet, danach die numerischen Variablen.
# So sieht man schnell, ob es auffällige Verteilungen oder unerwartete Werte gibt.

# %% [markdown]
# ### 3.1 Kategorische Variablen

# %%
kategorische_spalten = df.select_dtypes(include=["object"]).columns
kategorische_spalten
# Out:
# Index(['purpose'], dtype='object')

# %%
for spalte in kategorische_spalten:
    plt.figure(figsize=(7, 4))
    sns.countplot(data=df, x=spalte, order=df[spalte].value_counts().index)
    plt.title(f"Häufigkeitsverteilung von {spalte}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### 3.2 Numerische Variablen

# %%
numerische_spalten = df.select_dtypes(include=["int64", "float64"]).columns
print(numerische_spalten)
# Out:
# Index(['credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti',
#        'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df.select_dtypes(include="number").var().sort_values(ascending=False)
# Out:
# revol.bal            1.139480e+09
# days.with.cr.line    6.234661e+06
# installment          4.287852e+04
# fico                 1.441762e+03
# revol.util           8.418364e+02
# dti                  4.738904e+01
# inq.last.6mths       4.841079e+00
# log.annual.inc       3.779947e-01
# delinq.2yrs          2.983507e-01
# credit.policy        1.570099e-01
# not.fully.paid       1.344510e-01
# pub.rec              6.871021e-02
# int.rate             7.207607e-04
# dtype: float64

# %%
spalten_titel = {
    "credit.policy": "Erfüllung der Kreditrichtlinie",
    "int.rate": "Zinssatz des Kredits",
    "installment": "Monatliche Kreditrate",
    "log.annual.inc": "Logarithmiertes Jahreseinkommen",
    "dti": "Schulden-zu-Einkommen-Verhältnis",
    "fico": "FICO-Kredit-Score",
    "days.with.cr.line": "Dauer der Kredithistorie",
    "revol.bal": "Revolving-Kreditkontostand",
    "revol.util": "Nutzung des Kreditlimits (%)",
    "inq.last.6mths": "Kreditanfragen in den letzten 6 Monaten",
    "delinq.2yrs": "Zahlungsverzüge in den letzten 2 Jahren",
    "pub.rec": "Öffentliche negative Einträge",
    "not.fully.paid": "Kredit nicht vollständig zurückgezahlt",
}

for spalte in numerische_spalten:
    plt.figure(figsize=(7, 4))
    sns.histplot(df[spalte], bins=30, kde=True)
    plt.title(f"Verteilung von {spalten_titel.get(spalte, spalte)}")
    plt.tight_layout()
    plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df[numerische_spalten].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Korrelationsmatrix der numerischen Variablen")
plt.tight_layout()
plt.show()

# %%
print("FICO Min/Max:", df["fico"].min(), df["fico"].max())
print("\nInterest Rate:")
print(df["int.rate"].describe())
print("\nRevolving Utilization:")
print(df["revol.util"].describe())
# Out:
# FICO Min/Max: 612 827
#
# Interest Rate:
# count    9578.000000
# mean        0.122640
# std         0.026847
# min         0.060000
# 25%         0.103900
# 50%         0.122100
# 75%         0.140700
# max         0.216400
# Name: int.rate, dtype: float64
#
# Revolving Utilization:
# count    9578.000000
# mean       46.799236
# std        29.014417
# min         0.000000
# 25%        22.600000
# 50%        46.300000
# 75%        70.900000
# max       119.000000
# Name: revol.util, dtype: float64

# %% [markdown]
# ## 4. Datenvalidierung mit Great Expectations
#
# Im nächsten Schritt werden einfache Regeln für den Datensatz definiert.
# Damit lässt sich prüfen, ob die Struktur und die Werte grundsätzlich zu den Erwartungen passen.

# %%
context = ge.get_context(mode="ephemeral")
data_source = context.data_sources.add_pandas("pandas")
data_asset = data_source.add_dataframe_asset(name="loan_dataframe")

try:
    batch_definition = data_asset.get_batch_definition("whole_dataframe")
except Exception:
    batch_definition = data_asset.add_batch_definition_whole_dataframe("whole_dataframe")

batch = batch_definition.get_batch(batch_parameters={"dataframe": df})
validator = context.get_validator(batch=batch, create_expectation_suite_with_name="loan_suite")
validator

# %%
validator.expect_table_columns_to_match_ordered_list([
    "credit.policy", "purpose", "int.rate", "installment", "log.annual.inc", "dti", "fico",
    "days.with.cr.line", "revol.bal", "revol.util", "inq.last.6mths", "delinq.2yrs",
    "pub.rec", "not.fully.paid"
])

for col in df.columns:
    validator.expect_column_values_to_not_be_null(col)

validator.expect_column_values_to_be_in_set("credit.policy", [0, 1])
validator.expect_column_values_to_be_in_set("not.fully.paid", [0, 1])

validator.expect_column_values_to_be_in_set(
    "purpose",
    [
        "credit_card",
        "debt_consolidation",
        "educational",
        "major_purchase",
        "small_business",
        "all_other",
        "home_improvement",
    ],
)

validator.expect_column_values_to_be_between("fico", min_value=300, max_value=850)
validator.expect_column_values_to_be_between("int.rate", min_value=0, max_value=1)
validator.expect_column_values_to_be_between("installment", min_value=0)
validator.expect_column_values_to_be_between("dti", min_value=0, max_value=100)
validator.expect_column_values_to_be_between("revol.util", min_value=0, max_value=120)
validator.expect_column_values_to_be_between("log.annual.inc", min_value=7, max_value=15)
validator.expect_column_values_to_be_between("days.with.cr.line", min_value=0)
validator.expect_column_values_to_be_between("revol.bal", min_value=0)

for col in ["inq.last.6mths", "delinq.2yrs", "pub.rec"]:
    validator.expect_column_values_to_be_between(col, min_value=0)

result = validator.validate()
print("Gesamterfolg der Validierung:", result.success)
print("Anzahl geprüfter Expectations:", len(result.results))

failed_results = [res for res in result.results if not res.success]
print("Anzahl fehlgeschlagener Checks:", len(failed_results))
# Out:
# c:\Users\bjoer\AppData\Local\Programs\Python\Python311\Lib\site-packages\great_expectations\expectations\expectation.py:1659: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 569.88it/s]
# c:\Users\bjoer\AppData\Local\Programs\Python\Python311\Lib\site-packages\great_expectations\expectations\expectation.py:1659: UserWarning: `result_format` configured at the Validator-level will not be persisted. Please add the configuration to your Checkpoint config or checkpoint_run() method instead.
#   warnings.warn(
# Calculating Metrics: 100%|██████████| 6/6 [00:00<00:00, 921.29it/s]
# ...

# %% [markdown]
# ## 5. Validierten Datensatz speichern

# %%
Path("../data/processed").mkdir(parents=True, exist_ok=True)
df.to_csv("../data/processed/loan_data_validated.csv", index=False)
print("Validierter Datensatz wurde gespeichert: ../data/processed/loan_data_validated.csv")
# Out:
# Validierter Datensatz wurde gespeichert: ../data/processed/loan_data_validated.csv
